# %% [markdown]
# ## 1
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        seen = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i
            

# Test the function
nums = [2, 3,6,15, 11, 7]
target = 9

result = Solution().twoSum(nums, target)
print("Output:", result)
# Out:
# Output: [1, 2]

# %% [markdown]
# ## 2. Add Two Numbers
# You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
# ![Add Two Numbers](image/2.jpg)
#
#
# Example 1:
#
#
# Input: l1 = [2,4,3], l2 = [5,6,4]
# Output: [7,0,8]
# Explanation: 342 + 465 = 807.
# Example 2:
#
# Input: l1 = [0], l2 = [0]
# Output: [0]
# Example 3:
#
# Input: l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9]
# Output: [8,9,9,9,0,0,0,1]

# %%
from typing import Optional


class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def addTwoNumbers(self, l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:
        
        l1_list=[]
        l2_list=[]
        num_str1 = ""
        num_str2 = ""
        
        end = len(l1)
        for i in l1:
            l1_list.append(l1[end - 1])
            end = end - 1
        print(l1_list)
        
        
        end = len(l2)
        for i in l2:
            l2_list.append(l2[end - 1])
            end = end - 1
        print(l2_list)
        
        
        for i in l1_list:           
            num_str1 = num_str1 + str(i)   
        l1_num = int(num_str1)       
        print(l1_num)
        
        for i in l2_list:           
            num_str2 = num_str2 + str(i)   
        l2_num = int(num_str2)       
        print(l2_num)

        total = l1_num + l2_num
        
        total_str = str(total)
        total_list = []

        end = len(total_str)
        for i in total_str:
            total_list.append(int(total_str[end - 1]))
            end -= 1
            
        result = int("".join(str(i) for i in total_list))
        return result             
# Test the function
l1 = [2,4,3]
l2 = [5,6,4]


result = Solution().addTwoNumbers(l1, l2)
print("Output:", result)

# ساخت 3 گره برای عدد 342
node3 = ListNode(3)
node2 = ListNode(4, node3)
node1 = ListNode(2, node2)
# Out:
# [3, 4, 2]
# [4, 6, 5]
# 342
# 465
# Output: 708

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# خب اول باید اعداد برعکس رو بگیرم
#
#  یعنی باید
# اول بیایم و انتهای لیست بدونم کجاست
# و هر بار ازش کم کن و به لیست دیگه اضافه کنم
# و بعد اینکه لیست جدید ساختم
# بیام به اینت تبدیل کنم
# بعد جمع بزنم
#
#
#
#
# </div>

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:
        def to_int(node):
            s = ''
            while node:
                s = str(node.val) + s
                node = node.next
            return int(s)

        total = to_int(l1) + to_int(l2)
        head = cur = ListNode()
        for d in str(total)[::-1]:
            cur.next = ListNode(int(d))
            cur = cur.next
        return head.next

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# خب اینو انجام دادم و باه وش مصنوعی انجام دادم ونتیجه همداد اما
# </div>

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters
# Medium
# Topics
# premium lock icon
# Companies
# Hint
# Given a string s, find the length of the longest substring without duplicate characters.
#
#
#
# Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
#
#
# Constraints:
#
# 0 <= s.length <= 5 * 104
# s consists of English letters, digits, symbols and spaces.

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        seen = {}
        start = 0
        max_len = 0

        for i in range(len(s)):
            ch = s[i]
            if ch in seen and seen[ch] >= start:
                start = seen[ch] + 1
            seen[ch] = i
            max_len = max(max_len, i - start + 1)

        return max_len

# %%
result = Solution().lengthOfLongestSubstring("pwwkew")
print(result)
# Out:
# 3

# %% [markdown]
# ### 4. Median of Two Sorted Arrays
# Hard
# Topics
# premium lock icon
# Companies
# Given two sorted arrays nums1 and nums2 of size m and n respectively, return the median of the two sorted arrays.
#
# The overall run time complexity should be O(log (m+n)).
#
#
#
# Example 1:
#
# Input: nums1 = [1,3], nums2 = [2]
# Output: 2.00000
# Explanation: merged array = [1,2,3] and median is 2.
# Example 2:
#
# Input: nums1 = [1,2], nums2 = [3,4]
# Output: 2.50000
# Explanation: merged array = [1,2,3,4] and median is (2 + 3) / 2 = 2.5.
#
#
# Constraints:
#
# nums1.length == m
# nums2.length == n
# 0 <= m <= 1000
# 0 <= n <= 1000
# 1 <= m + n <= 2000
# -106 <= nums1[i], nums2[i] <= 106

# %%
class Solution:
    def findMedianSortedArrays(self, nums1, nums2):

        total = len(nums1) + len(nums2)
        half = total // 2

        # IF: nums1 entirely before nums2
        if nums1 and nums2 and nums1[-1] < nums2[0]:
            if total % 2:
                if half < len(nums1):
                    return nums1[half]
                return nums2[half - len(nums1)]
            else:
                if half < len(nums1):
                    return (nums1[half-1] + nums1[half]) / 2
                elif half == len(nums1):
                    return (nums1[-1] + nums2[0]) / 2
                else:
                    a = nums2[half - len(nums1) - 1]
                    b = nums2[half - len(nums1)]
                    return (a + b) / 2

        # ELIF: nums2 entirely before nums1
        elif nums1 and nums2 and nums2[-1] < nums1[0]:
            if total % 2:
                if half < len(nums2):
                    return nums2[half]
                return nums1[half - len(nums2)]
            else:
                if half < len(nums2):
                    return (nums2[half-1] + nums2[half]) / 2
                elif half == len(nums2):
                    return (nums2[-1] + nums1[0]) / 2
                else:
                    a = nums1[half - len(nums2) - 1]
                    b = nums1[half - len(nums2)]
                    return (a + b) / 2

        # ELSE → CUT section
        else:
            A, B = nums1, nums2
            if len(A) > len(B):
                A, B = B, A

            left, right = 0, len(A) - 1

            while True:
                cutA = (left + right) // 2
                cutB = half - cutA - 2

                L1 = A[cutA] if cutA >= 0 else float("-inf")
                R1 = A[cutA + 1] if (cutA + 1) < len(A) else float("inf")
                L2 = B[cutB] if cutB >= 0 else float("-inf")
                R2 = B[cutB + 1] if (cutB + 1) < len(B) else float("inf")

                if L1 <= R2 and L2 <= R1:
                    if total % 2:
                        return min(R1, R2)
                    return (max(L1, L2) + min(R1, R2)) / 2

                elif L1 > R2:
                    right = cutA - 1
                else:
                    left = cutA + 1

# %%
print(Solution().findMedianSortedArrays([1,2,3], [10,20,30]))
print(Solution().findMedianSortedArrays([50,60,70], [1,2,3]))
print(Solution().findMedianSortedArrays([1,5,10], [2,6,11]))
print(Solution().findMedianSortedArrays([1,3,8], [2,6,10,11]))
print(Solution().findMedianSortedArrays([2,5,7,12], [1,4,6,9,15]))
print(Solution().findMedianSortedArrays([1,2,99], [3,4,5,6,7,8]))
# Out:
# 6.5
# 26.5
# 5.5
# 6
# 6
# 5

# %%
class Solution:
    def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:

        A, B = nums1, nums2
        if len(A) > len(B):
            A, B = B, A

        total = len(A) + len(B)
        half = total // 2

        left, right = 0, len(A) - 1

        while True:
            cutA = (left + right) // 2
            cutB = half - cutA - 2

            L1 = A[cutA] if cutA >= 0 else float("-inf")
            R1 = A[cutA + 1] if (cutA + 1) < len(A) else float("inf")
            L2 = B[cutB] if cutB >= 0 else float("-inf")
            R2 = B[cutB + 1] if (cutB + 1) < len(B) else float("inf")

            if L1 <= R2 and L2 <= R1:
                if total % 2:
                    return float(min(R1, R2))
                return (max(L1, L2) + min(R1, R2)) / 2

            elif L1 > R2:
                right = cutA - 1
            else:
                left = cutA + 1

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# این جواب بالا امتیاز صد میگیرد
# اما چون من میخوام که خودم نوشته باشم
# قسمت شورتکات رو هم اضافه کرد
# که بدون اون امتیاز کامل تر میگیریم درلیت کد
# </div>

# %% [markdown]
# ### 5. Longest Palindromic Substring
# Medium
# Topics
# premium lock icon
# Companies
# Hint
# Given a string s, return the longest palindromic substring in s.
#
#
#
# Example 1:
#
# Input: s = "babad"
# Output: "bab"
# Explanation: "aba" is also a valid answer.
# Example 2:
#
# Input: s = "cbbd"
# Output: "bb"
#
#
# Constraints:
#
# 1 <= s.length <= 1000
# s consist of only digits and English letters.
