# %% [markdown]
# ## 1
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.

# %%
class Solution:
    def twoSum(self, nums: list[int], target: int) -> list[int]:
        seen = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in seen:
                return [seen[complement], i]
            
            seen[num] = i
            

# Test the function
nums = [2, 3,6,15, 11, 7]
target = 9

result = Solution().twoSum(nums, target)
print("Output:", result)
# Out:
# Output: [1, 2]

# %% [markdown]
# ## 2. Add Two Numbers
# You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
# ![Add Two Numbers](image/2.jpg)
#
#
# Example 1:
#
#
# Input: l1 = [2,4,3], l2 = [5,6,4]
# Output: [7,0,8]
# Explanation: 342 + 465 = 807.
# Example 2:
#
# Input: l1 = [0], l2 = [0]
# Output: [0]
# Example 3:
#
# Input: l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9]
# Output: [8,9,9,9,0,0,0,1]

# %%
from typing import Optional


class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def addTwoNumbers(self, l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:
        
        l1_list=[]
        l2_list=[]
        num_str1 = ""
        num_str2 = ""
        
        end = len(l1)
        for i in l1:
            l1_list.append(l1[end - 1])
            end = end - 1
        print(l1_list)
        
        
        end = len(l2)
        for i in l2:
            l2_list.append(l2[end - 1])
            end = end - 1
        print(l2_list)
        
        
        for i in l1_list:           
            num_str1 = num_str1 + str(i)   
        l1_num = int(num_str1)       
        print(l1_num)
        
        for i in l2_list:           
            num_str2 = num_str2 + str(i)   
        l2_num = int(num_str2)       
        print(l2_num)

        total = l1_num + l2_num
        
        total_str = str(total)
        total_list = []

        end = len(total_str)
        for i in total_str:
            total_list.append(int(total_str[end - 1]))
            end -= 1
            
        result = int("".join(str(i) for i in total_list))
        return result             
# Test the function
l1 = [2,4,3]
l2 = [5,6,4]


result = Solution().addTwoNumbers(l1, l2)
print("Output:", result)

# ساخت 3 گره برای عدد 342
node3 = ListNode(3)
node2 = ListNode(4, node3)
node1 = ListNode(2, node2)
# Out:
# [3, 4, 2]
# [4, 6, 5]
# 342
# 465
# Output: 708

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# خب اول باید اعداد برعکس رو بگیرم
#
#  یعنی باید
# اول بیایم و انتهای لیست بدونم کجاست
# و هر بار ازش کم کن و به لیست دیگه اضافه کنم
# و بعد اینکه لیست جدید ساختم
# بیام به اینت تبدیل کنم
# بعد جمع بزنم
#
#
#
#
# </div>

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: Optional[ListNode], l2: Optional[ListNode]) -> Optional[ListNode]:
        def to_int(node):
            s = ''
            while node:
                s = str(node.val) + s
                node = node.next
            return int(s)

        total = to_int(l1) + to_int(l2)
        head = cur = ListNode()
        for d in str(total)[::-1]:
            cur.next = ListNode(int(d))
            cur = cur.next
        return head.next

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# خب اینو انجام دادم و باه وش مصنوعی انجام دادم ونتیجه همداد اما
# </div>

# %% [markdown]
# ### 3. Longest Substring Without Repeating Characters
# Medium
# Topics
# premium lock icon
# Companies
# Hint
# Given a string s, find the length of the longest substring without duplicate characters.
#
#
#
# Example 1:
#
# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.
# Example 2:
#
# Input: s = "bbbbb"
# Output: 1
# Explanation: The answer is "b", with the length of 1.
# Example 3:
#
# Input: s = "pwwkew"
# Output: 3
# Explanation: The answer is "wke", with the length of 3.
# Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
#
#
# Constraints:
#
# 0 <= s.length <= 5 * 104
# s consists of English letters, digits, symbols and spaces.

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        seen = {}
        start = 0
        max_len = 0

        for i in range(len(s)):
            ch = s[i]
            if ch in seen and seen[ch] >= start:
                start = seen[ch] + 1
            seen[ch] = i
            max_len = max(max_len, i - start + 1)

        return max_len

# %%
result = Solution().lengthOfLongestSubstring("pwwkew")
print(result)
# Out:
# 3

# %% [markdown]
# ### 4. Median of Two Sorted Arrays
# Hard
# Topics
# premium lock icon
# Companies
# Given two sorted arrays nums1 and nums2 of size m and n respectively, return the median of the two sorted arrays.
#
# The overall run time complexity should be O(log (m+n)).
#
#
#
# Example 1:
#
# Input: nums1 = [1,3], nums2 = [2]
# Output: 2.00000
# Explanation: merged array = [1,2,3] and median is 2.
# Example 2:
#
# Input: nums1 = [1,2], nums2 = [3,4]
# Output: 2.50000
# Explanation: merged array = [1,2,3,4] and median is (2 + 3) / 2 = 2.5.
#
#
# Constraints:
#
# nums1.length == m
# nums2.length == n
# 0 <= m <= 1000
# 0 <= n <= 1000
# 1 <= m + n <= 2000
# -106 <= nums1[i], nums2[i] <= 106

# %%
class Solution:
    def findMedianSortedArrays(self, nums1, nums2):

        total = len(nums1) + len(nums2)
        half = total // 2

        # IF: nums1 entirely before nums2
        if nums1 and nums2 and nums1[-1] < nums2[0]:
            if total % 2:
                if half < len(nums1):
                    return nums1[half]
                return nums2[half - len(nums1)]
            else:
                if half < len(nums1):
                    return (nums1[half-1] + nums1[half]) / 2
                elif half == len(nums1):
                    return (nums1[-1] + nums2[0]) / 2
                else:
                    a = nums2[half - len(nums1) - 1]
                    b = nums2[half - len(nums1)]
                    return (a + b) / 2

        # ELIF: nums2 entirely before nums1
        elif nums1 and nums2 and nums2[-1] < nums1[0]:
            if total % 2:
                if half < len(nums2):
                    return nums2[half]
                return nums1[half - len(nums2)]
            else:
                if half < len(nums2):
                    return (nums2[half-1] + nums2[half]) / 2
                elif half == len(nums2):
                    return (nums2[-1] + nums1[0]) / 2
                else:
                    a = nums1[half - len(nums2) - 1]
                    b = nums1[half - len(nums2)]
                    return (a + b) / 2

        # ELSE → CUT section
        else:
            A, B = nums1, nums2
            if len(A) > len(B):
                A, B = B, A

            left, right = 0, len(A) - 1

            while True:
                cutA = (left + right) // 2
                cutB = half - cutA - 2

                L1 = A[cutA] if cutA >= 0 else float("-inf")
                R1 = A[cutA + 1] if (cutA + 1) < len(A) else float("inf")
                L2 = B[cutB] if cutB >= 0 else float("-inf")
                R2 = B[cutB + 1] if (cutB + 1) < len(B) else float("inf")

                if L1 <= R2 and L2 <= R1:
                    if total % 2:
                        return min(R1, R2)
                    return (max(L1, L2) + min(R1, R2)) / 2

                elif L1 > R2:
                    right = cutA - 1
                else:
                    left = cutA + 1

# %%
print(Solution().findMedianSortedArrays([1,2,3], [10,20,30]))
print(Solution().findMedianSortedArrays([50,60,70], [1,2,3]))
print(Solution().findMedianSortedArrays([1,5,10], [2,6,11]))
print(Solution().findMedianSortedArrays([1,3,8], [2,6,10,11]))
print(Solution().findMedianSortedArrays([2,5,7,12], [1,4,6,9,15]))
print(Solution().findMedianSortedArrays([1,2,99], [3,4,5,6,7,8]))
# Out:
# 6.5
# 26.5
# 5.5
# 6
# 6
# 5

# %%
class Solution:
    def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:

        A, B = nums1, nums2
        if len(A) > len(B):
            A, B = B, A

        total = len(A) + len(B)
        half = total // 2

        left, right = 0, len(A) - 1

        while True:
            cutA = (left + right) // 2
            cutB = half - cutA - 2

            L1 = A[cutA] if cutA >= 0 else float("-inf")
            R1 = A[cutA + 1] if (cutA + 1) < len(A) else float("inf")
            L2 = B[cutB] if cutB >= 0 else float("-inf")
            R2 = B[cutB + 1] if (cutB + 1) < len(B) else float("inf")

            if L1 <= R2 and L2 <= R1:
                if total % 2:
                    return float(min(R1, R2))
                return (max(L1, L2) + min(R1, R2)) / 2

            elif L1 > R2:
                right = cutA - 1
            else:
                left = cutA + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 class Solution:
#       2     def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:
#       4         A, B = nums1, nums2
#
# Cell In[74], line 2, in Solution()
#       1 class Solution:
# ----> 2     def findMedianSortedArrays(self, nums1: List[int], nums2: List[int]) -> float:
#       4         A, B = nums1, nums2
#       5         if len(A) > len(B):
#
# NameError: name 'List' is not defined

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# این جواب بالا امتیاز صد میگیرد
# اما چون من میخوام که خودم نوشته باشم
# قسمت شورتکات رو هم اضافه کرد
# که بدون اون امتیاز کامل تر میگیریم درلیت کد
# </div>

# %% [markdown]
# ### 5. Longest Palindromic Substring
# Medium
# Topics
# premium lock icon
# Companies
# Hint
# Given a string s, return the longest palindromic substring in s.
#
#
#
# Example 1:
#
# Input: s = "babad"
# Output: "bab"
# Explanation: "aba" is also a valid answer.
# Example 2:
#
# Input: s = "cbbd"
# Output: "bb"
#
#
# Constraints:
#
# 1 <= s.length <= 1000
# s consist of only digits and English letters.

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        if len(s) < 2:
            return s
        
        start = 0
        max_len = 1
        
        def expand(l, r):
            while l >= 0 and r < len(s) and s[l] == s[r]:
                l -= 1
                r += 1
            return l + 1, r - 1
        
        for i in range(len(s)):
            left, right = expand(i, i)
            curr_len = right - left + 1
            if curr_len > max_len:
                max_len = curr_len
                start = left

            left, right = expand(i, i + 1)
            curr_len = right - left + 1
            if curr_len > max_len:
                max_len = curr_len
                start = left

        return s[start:start + max_len]

# %%
class Solution:
    def longestPalindrome(self, s: str) -> str:
        if len(s) < 2:
            return s
        
        start = 0
        max_len = 1
        
        def expand(l, r):
            while l >= 0 and r < len(s) and s[l] == s[r]:
                l -= 1
                r += 1
            return l + 1, r - 1
        
        for i in range(len(s)):
            left, right = expand(i, i)
            curr_len = right - left + 1
            if curr_len > max_len:
                max_len = curr_len
                start = left

            left, right = expand(i, i + 1)
            curr_len = right - left + 1
            if curr_len > max_len:
                max_len = curr_len
                start = left
        
        return s[start:start + max_len]

# %%
sol = Solution()
print(sol.longestPalindrome("babad"))
print(sol.longestPalindrome("cbbd"))
print(sol.longestPalindrome("cfghhgne"))
print(sol.longestPalindrome("abba"))
# Out:
# bab
# bb
# ghhg
# abba

# %% [markdown]
# 6. Zigzag Conversion
# Medium
# Topics
# premium lock icon
# Companies
# The string "PAYPALISHIRING" is written in a zigzag pattern on a given number of rows like this: (you may want to display this pattern in a fixed font for better legibility)
#
# P   A   H   N
# A P L S I I G
# Y   I   R
# And then read line by line: "PAHNAPLSIIGYIR"
#
# Write the code that will take a string and make this conversion given a number of rows:
#
# string convert(string s, int numRows);
#
#
# Example 1:
#
# Input: s = "PAYPALISHIRING", numRows = 3
# Output: "PAHNAPLSIIGYIR"
# Example 2:
#
# Input: s = "PAYPALISHIRING", numRows = 4
# Output: "PINALSIGYAHRPI"
# Explanation:
# P     I    N
# A   L S  I G
# Y A   H R
# P     I
# Example 3:
#
# Input: s = "A", numRows = 1
# Output: "A"
#
#
# Constraints:
#
# 1 <= s.length <= 1000
# s consists of English letters (lower-case and upper-case), ',' and '.'.
# 1 <= numRows <= 1000

# %%
class Solution:
    def convert(self, s: str, numRows: int) -> str:
        if numRows == 1 or numRows >= len(s):
            return s
        
        rows = [""] * numRows
        current_row = 0
        direction = 1
        
        for i in range(len(s)):
            rows[current_row] += s[i]

            current_row += direction

            if current_row == numRows - 1:
                direction = -1
            elif current_row == 0:
                direction = 1

        return "".join(rows)

# %% [markdown]
# ### 7. Reverse Integer
# Medium
# Topics
# premium lock icon
# Companies
# Given a signed 32-bit integer x, return x with its digits reversed. If reversing x causes the value to go outside the signed 32-bit integer range [-231, 231 - 1], then return 0.
#
# Assume the environment does not allow you to store 64-bit integers (signed or unsigned).
#
#
#
# Example 1:
#
# Input: x = 123
# Output: 321
# Example 2:
#
# Input: x = -123
# Output: -321
# Example 3:
#
# Input: x = 120
# Output: 21
#
#
# Constraints:
#
# -231 <= x <= 231 - 1

# %%
class Solution:
    def reverse(self, x: int) -> int:
        
        INT_MAX = 2147483647
        INT_MIN = -2147483648
        
        sign = 1
        if x < 0:
            sign = -1

        x = abs(x)
        
        result = 0
        
        while x != 0:
            digit = x % 10
            x = x // 10
            
            if result > INT_MAX // 10 or (result == INT_MAX // 10 and digit > 7):
                return 0
            
            result = result * 10 + digit
        
        return sign * result

# %%
sol = Solution()

print(sol.reverse(123))        # 321
print(sol.reverse(-123))       # -321
print(sol.reverse(120))        # 21
print(sol.reverse(0))          # 0
print(sol.reverse(1534236469)) # 0 (overflow)
print(sol.reverse(1463847412)) # 2147483641 (safe)
print(sol.reverse(2147483647)) # 0 (overflow)
print(sol.reverse(-2147483412))# -2143847412 (safe)
# Out:
# 321
# -321
# 21
# 0
# 0
# 2147483641
# 0
# -2143847412

# %% [markdown]
# ### 8. String to Integer (atoi)
# Medium
# Topics
# premium lock icon
# Companies
# Implement the myAtoi(string s) function, which converts a string to a 32-bit signed integer.
#
# The algorithm for myAtoi(string s) is as follows:
#
# Whitespace: Ignore any leading whitespace (" ").
# Signedness: Determine the sign by checking if the next character is '-' or '+', assuming positivity if neither present.
# Conversion: Read the integer by skipping leading zeros until a non-digit character is encountered or the end of the string is reached. If no digits were read, then the result is 0.
# Rounding: If the integer is out of the 32-bit signed integer range [-231, 231 - 1], then round the integer to remain in the range. Specifically, integers less than -231 should be rounded to -231, and integers greater than 231 - 1 should be rounded to 231 - 1.
# Return the integer as the final result.
#
#
#
# Example 1:
#
# Input: s = "42"
#
# Output: 42
#
# Explanation:
#
# The underlined characters are what is read in and the caret is the current reader position.
# Step 1: "42" (no characters read because there is no leading whitespace)
#          ^
# Step 2: "42" (no characters read because there is neither a '-' nor '+')
#          ^
# Step 3: "42" ("42" is read in)
#            ^
# Example 2:
#
# Input: s = " -042"
#
# Output: -42
#
# Explanation:
#
# Step 1: "   -042" (leading whitespace is read and ignored)
#             ^
# Step 2: "   -042" ('-' is read, so the result should be negative)
#              ^
# Step 3: "   -042" ("042" is read in, leading zeros ignored in the result)
#                ^
# Example 3:
#
# Input: s = "1337c0d3"
#
# Output: 1337
#
# Explanation:
#
# Step 1: "1337c0d3" (no characters read because there is no leading whitespace)
#          ^
# Step 2: "1337c0d3" (no characters read because there is neither a '-' nor '+')
#          ^
# Step 3: "1337c0d3" ("1337" is read in; reading stops because the next character is a non-digit)
#              ^
# Example 4:
#
# Input: s = "0-1"
#
# Output: 0
#
# Explanation:
#
# Step 1: "0-1" (no characters read because there is no leading whitespace)
#          ^
# Step 2: "0-1" (no characters read because there is neither a '-' nor '+')
#          ^
# Step 3: "0-1" ("0" is read in; reading stops because the next character is a non-digit)
#           ^
# Example 5:
#
# Input: s = "words and 987"
#
# Output: 0
#
# Explanation:
#
# Reading stops at the first non-digit character 'w'.
#
#
#
# Constraints:
#
# 0 <= s.length <= 200
# s consists of English letters (lower-case and upper-case), digits (0-9), ' ', '+', '-', and '.'.

# %%
class Solution:
    def myAtoi(self, s: str) -> int:
        n = len(s)
        i = 0

        # 1) Skip leading spaces
        while i < n and s[i] == ' ':
            i += 1

        # If string is empty after trimming spaces -> 0
        if i == n:
            return 0

        # TEMP: for step-1 verification only (we'll remove later)
        return i

# %%
sol = Solution()
print(sol.myAtoi("42"))        # expect 0 (no leading spaces)
print(sol.myAtoi("   -042"))   # expect 3
print(sol.myAtoi("      "))    # expect 0 (because we return 0 when i==n)
# Out:
# 0
# 3
# 0

# %%
class Solution:
    def myAtoi(self, s: str) -> int:
        INT_MAX = 2147483647
        INT_MIN = -2147483648

        n = len(s)
        i = 0

        # 1) skip leading spaces
        while i < n and s[i] == ' ':
            i += 1
        if i == n:
            return 0

        # 2) sign
        sign = 1
        if s[i] == '+' or s[i] == '-':
            if s[i] == '-':
                sign = -1
            i += 1

        # 3) read digits
        result = 0
        has_digit = False

        while i < n and '0' <= s[i] <= '9':
            has_digit = True
            digit = ord(s[i]) - ord('0')

            # 4) overflow check (same idea as question 7)
            if result > INT_MAX // 10 or (
                result == INT_MAX // 10 and digit > 7
            ):
                return INT_MAX if sign == 1 else INT_MIN

            result = result * 10 + digit
            i += 1

        # 5) no digits read
        if not has_digit:
            return 0

        return sign * result

# %%
sol = Solution()

tests = [
    "42",
    "   -042",
    "      ",
    "4193 with words",
    "words and 987",
    "-2147483649",
    "2147483648",
    "-.5",
    "5.-",
    "+",
]

for t in tests:
    print(f'"{t}" -> {sol.myAtoi(t)}')
# Out:
# "42" -> 42
# "   -042" -> -42
# "      " -> 0
# "4193 with words" -> 4193
# "words and 987" -> 0
# "-2147483649" -> -2147483648
# "2147483648" -> 2147483647
# "-.5" -> 0
# "5.-" -> 5
# "+" -> 0

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# سؤال‌هات کاملاً درستن؛ بذار **خیلی دقیق ولی ساده** جواب بدم، بدون فلسفه‌بافی.
#
# ---
#
# ## 1️⃣ `'0' <= s[i] <= '9'` یعنی چی؟
#
# بله، **سیستم می‌فهمه**.
#
# در پایتون:
#
# * کاراکترها (`'0'`, `'9'`, `'a'`) هم **مقدار عددی داخلی** دارن (Unicode)
# * مقایسه‌ی رشته‌ای تک‌کاراکتری یعنی مقایسه‌ی **کد عددی**
#
# پس این شرط یعنی:
#
# > «کد کاراکتر `s[i]` بین کد `'0'` و `'9'` هست یا نه»
#
# نتیجه:
#
# * `'5'` ✅
# * `'a'` ❌
# * `'.'` ❌
# * `' '` ❌
#
# یعنی:
# 👉 فقط **digit واقعی**، نه هیچ کاراکتر دیگه‌ای
#
# ---
#
# ## 2️⃣ `ord()` چی هست؟
#
# `ord()` یک **تابع builtin پایتون**ه.
#
# ```python
# ord('0') == 48
# ord('9') == 57
# ```
#
# پس:
#
# ```python
# ord(s[i]) - ord('0')
# ```
#
# یعنی:
#
# > «عدد واقعیِ این رقم چنده؟»
#
# مثال:
#
# * `'7'` → `55 - 48 = 7`
# * `'0'` → `48 - 48 = 0`
#
# ---
#
# ## 3️⃣ چرا اصلاً از `ord` استفاده می‌کنیم؟
#
# چون:
#
# * سریع‌تره
# * مستقل از locale
# * دقیقاً همون کاریه که زبان‌های پایین‌سطح (C/C++) می‌کنن
# * در مصاحبه‌ها و LeetCode **روش استاندارد parser**
#
# ---
#
# ## 4️⃣ چرا نمی‌گیم `int(s[i])`؟
#
# می‌تونیم، ولی **نباید** در این سؤال.
#
# چرا؟
#
# * `int()` خودش parser کامل داره
# * اگر `s[i]` غیررقم باشه → exception
# * ما داریم **parser می‌نویسیم**، نه استفاده می‌کنیم
#
# atoi یعنی:
#
# > «بدون کمک گرفتن از ابزار آماده، خودت عدد رو بساز»
#
# ---
#
# ## 5️⃣ چرا نمی‌گیم اول رشته‌ی عددی رو جمع کنیم بعد `int()` کنیم؟
#
# مثلاً:
#
# ```python
# num_str = ""
# num_str += s[i]
# return int(num_str)
# ```
#
# ❌ مشکل:
#
# * کنترل overflow از دست میره
# * منطق مرحله‌ای سؤال نقض می‌شه
# * LeetCode اینو قبول می‌کنه؟ شاید
#   ولی **مصاحبه نه**
#
# ---
#
# ## جمع‌بندی خیلی کوتاه
#
# * `'0' <= c <= '9'` → سیستم با Unicode می‌فهمه
# * `ord()` → تبدیل کاراکتر به کد عددی
# * `digit = ord(c) - ord('0')` → استاندارد parser
# * `int()` → استفاده نکن، چون تقلب منطقیه
#
#
# </div>

# %% [markdown]
# ### 9. Palindrome Number
# Easy
# Topics
# premium lock icon
# Companies
# Hint
# Given an integer x, return true if x is a palindrome, and false otherwise.
#
#
#
# Example 1:
#
# Input: x = 121
# Output: true
# Explanation: 121 reads as 121 from left to right and from right to left.
# Example 2:
#
# Input: x = -121
# Output: false
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
# Example 3:
#
# Input: x = 10
# Output: false
# Explanation: Reads 01 from right to left. Therefore it is not a palindrome.
#
#
# Constraints:
#
# -231 <= x <= 231 - 1
#
#
# Follow up: Could you solve it without converting the integer to a string?

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        if x < 0:
            return False
        if x != 0 and x % 10 == 0:
            return False

        reversed_half = 0
        while x > reversed_half:
            reversed_half = reversed_half * 10 + x % 10
            x //= 10

        return x == reversed_half or x == reversed_half // 10

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        if x < 0:
            return False
        if x != 0 and x % 10 == 0:
            return False

        reversed_half = 0
        while x > reversed_half:
            reversed_half = reversed_half * 10 + x % 10
            x //= 10

        if x == reversed_half or x == reversed_half // 10 :
            return True
        else:
            return False

# %%
sol = Solution()
print(sol.isPalindrome(121))   # placeholder True for now
print(sol.isPalindrome(-121))  # False
print(sol.isPalindrome(10))    # False
print(sol.isPalindrome(0))     # placeholder True for now
print(sol.isPalindrome(12321))
print(sol.isPalindrome(12325))
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1;">
# ما برای اینکه بتوانیم اینه اعداد را دربیاوریم باید مقایسه کنیم عدد اول و اخر را
# اما چون ما نمیتوانیم اعداد بزرگ را اولش را دربیارویم و نمیخواهیم از لیست استفاده کنیم
# پس میایم و نصف میکنیم
# و نصف اخر مساوی نصف اول شد
# یعنی عدد اینه هست .
# </div>

# %% [markdown]
# ### 10. Regular Expression Matching
# Hard
# Topics
# premium lock icon
# Companies
# Given an input string s and a pattern p, implement regular expression matching with support for '.' and '*' where:
#
# '.' Matches any single character.​​​​
# '*' Matches zero or more of the preceding element.
# The matching should cover the entire input string (not partial).
#
#
#
# Example 1:
#
# Input: s = "aa", p = "a"
# Output: false
# Explanation: "a" does not match the entire string "aa".
# Example 2:
#
# Input: s = "aa", p = "a*"
# Output: true
# Explanation: '*' means zero or more of the preceding element, 'a'. Therefore, by repeating 'a' once, it becomes "aa".
# Example 3:
#
# Input: s = "ab", p = ".*"
# Output: true
# Explanation: ".*" means "zero or more (*) of any character (.)".
#
#
# Constraints:
#
# 1 <= s.length <= 20
# 1 <= p.length <= 20
# s contains only lowercase English letters.
# p contains only lowercase English letters, '.', and '*'.
# It is guaranteed for each appearance of the character '*', there will be a previous valid character to match.

# %%
class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        l = []
        bchar = ""
        c,g,h = 0,0,0
        for char in p:
            print("char ===== ",char )
            if char == "*" :
                
                print("char with star")
                print(char)
                c +=1
                l.pop(-1)
                n = bchar + char
                if bchar == ".":
                    h -=1
                else:
                    g -=1
                print(n)
                locationofstar = (len(l))
                #print("location === ",locationofstar)
                l.append(n)
            else:
                if char == ".":
                    print("char is dot")
                    l.append(char)
                    h +=1
                else:
                    print("char is char ")
                    g +=1
                    l.append(char)
                    
                    
                    
            bchar = char
            
            
        print("char ======",g)
        print("*    ======",c)
        print(".    ======",h)
        print(l,s)
        print("absolute char in l is = ",g+h)
        absolute_char = g+h
        count_len =0
        if absolute_char > len(s):
            return False

            
        star = len(s) - absolute_char
        print(star)

        if star == 0:
            count_len = len(s)
            
        else:
            count_len = len(l)
            
            
            
        print("clen ===== ",count_len)
        
        
        
        #این قسمت باید درست شود به این ترتیب که بیایم و طول بزرگتر را که همیشه ال هست را کوتاه کنمی اندازه اس شود.
        for i in range(count_len):
            print(i)
            print(l[i],s[i])
            if l[i].endswith('*'):
                #l.pop(i)
                print(len(l),"=====",len(s))

                
                
                print(l,s)
            
                
                
            '''if l[i] == s[i]:
                if s[i] in l:
                    print("s[i] in l ======= ",s[i])
                print(i,l[i],s[i])
            else:
                print("here")
                token = l[i]
                print(token)
                if token.endswith('*'):
                    base = token[0]
                    if base == ".":
                        print("* with  .")
                    else:
                        print(base,s[i])
                        if base == s[i]:
                            print ("true")
                            print("* not  .")
                        
                else:
                    if l[i] == ".":
                        print ("char is . ")
        print(i, l[i], s[i])'''

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# یک ایرا د دیگری که وجود دارد پیمایش مینینم میخروه به اس
# ولی اگر با اس برویم کل رشته ال اصلا چاپ نمیشود و مثلا اگر ده تا نقطه داشته باشیم که هیچ کارکتری نگیرد اصا معنا نمیدهد
# و چون ما داریم از ابتدا میروم و دونه دونه به حالت فلگ ترو فالس چک میکنیم
#
# ممکنه است عدد ثابت را ستاره به جای خود بخورد
#
# 29 اذر
#
# تا اینجا نوشته شد که اگر اس کوتاه تر بود کارکتر های ستاره ای صفر شود در خوردن
# و اس ال مثل هم میشوند
# اما خود کارکتر ستاره و نقطه را باید کارکتر تهی بگیریم این یک کار
# کار بعد اینکه درتست اعداد مساوی اس بررسی شود کد
# کار بعد کلا تست شود
# کار بعد کارکتر نقطه هم گرفته شود به درستی
#
#
# یعنی ما اول میایم و ستاره دار رو میگیرم که قبلش هر چی بود با ستاره شه
# بعد نبود میشه کارکتر
# اما مممکنه خود نقطه هم باشه
# توی لیست ال ما نقطه و ستاره رو در میاریم در اونجایی که ستاره صفر شده
# اما در اصل ما توی غیر ستاره صفر نتوسنسیتم کارکتر نقطه رو پیدا کنیم و در بیارم
# یعنی چار حالته
# ستاره با نقطع
# ستاره با کارکتر
# کارکتر
# نقطه
# </div>

# %% [markdown]
# قانون‌ها:
#
# . → دقیقاً یک کاراکتر
#
# x* → صفر یا چند بار x
#
# .* → صفر یا چند بار هر کاراکتر
#
# تطبیق باید کل رشته رو بپوشونه (نه تیکه‌ای)

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# سه شنبه دوم دی ماه
#
# برای اینکه بتوانیم طول ها رو درست کینم
# اس طول گرفته شد
# و سعی کردیم اول ستاره ها را پاپ کنیم
# بعد دوباره طول را به دست بیاوریم
# و بعد انطباق انجام دهیم
# البته مشکل دارد قضیه
#
#
# چون اگر بخواهیم بگویم ستاره ها هیچی نگیرند مشکل میشود
# یا باید بگویم ستاره ها چند تا میگریند
# و تعدادش را در کل در بیارویم و بعد بگویم خب حالا
# چند تا مجاز بود و بعد انطباق دهیم
# </div>

# %%
sol = Solution()
print(sol.isMatch("ab",".*b"))
# Out:
# char =====  .
# char is dot
# char =====  *
# char with star
# *
# .*
# char =====  b
# char is char
# char ====== 1
# *    ====== 1
# .    ====== 0
# ['.*', 'b'] ab
# absolute char in l is =  1
# 1
# clen =====  2
# 0
# .* a
# 2 ===== 2
# ['.*', 'b'] ab
# 1
# b b
# None

# %%
sol = Solution()
print(sol.isMatch("ba","b.*a.*"))
# Out:
# char =====  b
# char is char
# char =====  .
# char is dot
# char =====  *
# char with star
# *
# .*
# char =====  a
# char is char
# char =====  .
# char is dot
# char =====  *
# char with star
# *
# .*
# char ====== 2
# *    ====== 2
# .    ====== 0
# ['b', '.*', 'a', '.*'] ba
# absolute char in l is =  2
# 0
# clen =====  2
# 0
# b b
# 1
# .* a
# 4 ===== 2
# ['b', '.*', 'a', '.*'] ba
# None

# %%
sol = Solution()
print(sol.isMatch("baa","b.*a"))
# Out:
# char =====  b
# char is char
# char =====  .
# char is dot
# char =====  *
# char with star
# *
# .*
# char =====  a
# char is char
# char ====== 2
# *    ====== 1
# .    ====== 0
# ['b', '.*', 'a'] baa
# absolute char in l is =  2
# 1
# clen =====  3
# 0
# b b
# 1
# .* a
# 3 ===== 3
# ['b', '.*', 'a'] baa
# 2
# a a
# None

# %%
sol = Solution()
print(sol.isMatch("ab","a*b*"))
# Out:
# char =====  a
# char is char
# char =====  *
# char with star
# *
# a*
# char =====  b
# char is char
# char =====  *
# char with star
# *
# b*
# char ====== 0
# *    ====== 2
# .    ====== 0
# ['a*', 'b*'] ab
# absolute char in l is =  0
# 2
# clen =====  2
# 0
# a* a
# 2 ===== 2
# ['a*', 'b*'] ab
# 1
# b* b
# 2 ===== 2
# ['a*', 'b*'] ab
# None

# %%
sol = Solution()
print(sol.isMatch("aaaab","aaa*ab"))
# Out:
# char =====  a
# char is char
# char =====  a
# char is char
# char =====  a
# char is char
# char =====  *
# char with star
# *
# a*
# char =====  a
# char is char
# char =====  b
# char is char
# char ====== 4
# *    ====== 1
# .    ====== 0
# ['a', 'a', 'a*', 'a', 'b'] aaaab
# absolute char in l is =  4
# 1
# clen =====  5
# 0
# a a
# 1
# a a
# 2
# a* a
# 5 ===== 5
# ['a', 'a', 'a*', 'a', 'b'] aaaab
# 3
# a a
# 4
# b b
# None

# %%
class Solution:
    def isMatch(self, s: str, p: str) -> bool:
        # 1) tokenize pattern
        tokens = []
        i = 0
        while i < len(p):
            if i + 1 < len(p) and p[i+1] == '*':
                tokens.append(p[i] + '*')
                i += 2
            else:
                tokens.append(p[i])
                i += 1

        # 2) recursive match
        def match(si, ti):
            if ti == len(tokens):
                return si == len(s)

            token = tokens[ti]

            # star case
            if token.endswith('*'):
                base = token[0]

                # option 1: zero occurrence
                if match(si, ti + 1):
                    return True

                # option 2: one or more
                if si < len(s) and (base == '.' or base == s[si]):
                    return match(si + 1, ti)

                return False

            # normal / dot
            if si < len(s) and (token == '.' or token == s[si]):
                return match(si + 1, ti + 1)

            return False

        return match(0, 0)

# %%
sol = Solution()

print(sol.isMatch("baa", "b.*a"))     # True
print(sol.isMatch("ab", ".*b"))       # True
print(sol.isMatch("ba", "b.*.*a."))   # False
print(sol.isMatch("aa", "a"))         # False
print(sol.isMatch("aa", "a*"))        # True
print(sol.isMatch("ab", ".*"))        # True
# Out:
# True
# True
# False
# False
# True
# True

# %% [markdown]
# 11. Container With Most Water
# Medium
# Topics
# premium lock icon
# Companies
# Hint
# You are given an integer array height of length n. There are n vertical lines drawn such that the two endpoints of the ith line are (i, 0) and (i, height[i]).
#
# Find two lines that together with the x-axis form a container, such that the container contains the most water.
#
# Return the maximum amount of water a container can store.
#
# Notice that you may not slant the container.
#
#
#
# Example 1:
#
#
# Input: height = [1,8,6,2,5,4,8,3,7]
# Output: 49
# Explanation: The above vertical lines are represented by array [1,8,6,2,5,4,8,3,7]. In this case, the max area of water (blue section) the container can contain is 49.
# Example 2:
#
# Input: height = [1,1]
# Output: 1
#
#
# Constraints:
#
# n == height.length
# 2 <= n <= 105
# 0 <= height[i] <= 104

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# باید حجم اب دربیاریم با دو تا ارتفاع که توی آرایه هست
# و کوچیکترین ارتفاع ملاک
# عرض هم میشه فاصله اندیس ها
# بخوایم با دو تا حلقه پیمایش کنیم نمیشه
# دوتا اشاره گر از چپ و راست میزاریم و میریم جلو و هربار کوچیکتر رو میبریم جلو و محاسبه میکنیم.
# </div>

# %%
class Solution:
    def maxArea(self, height):
        left = 0
        right = len(height) - 1
        max_area = 0

        while left < right:
            width = right - left
            h = min(height[left], height[right])
            area = width * h
            max_area = max(max_area, area)

            if height[left] < height[right]:
                left += 1
            else:
                right -= 1

        return max_area

# %% [markdown]
# 12. Integer to Roman
# Medium
# Topics
# premium lock icon
# Companies
# Seven different symbols represent Roman numerals with the following values:
#
# Symbol	Value
# I	1
# V	5
# X	10
# L	50
# C	100
# D	500
# M	1000
# Roman numerals are formed by appending the conversions of decimal place values from highest to lowest. Converting a decimal place value into a Roman numeral has the following rules:
#
# If the value does not start with 4 or 9, select the symbol of the maximal value that can be subtracted from the input, append that symbol to the result, subtract its value, and convert the remainder to a Roman numeral.
# If the value starts with 4 or 9 use the subtractive form representing one symbol subtracted from the following symbol, for example, 4 is 1 (I) less than 5 (V): IV and 9 is 1 (I) less than 10 (X): IX. Only the following subtractive forms are used: 4 (IV), 9 (IX), 40 (XL), 90 (XC), 400 (CD) and 900 (CM).
# Only powers of 10 (I, X, C, M) can be appended consecutively at most 3 times to represent multiples of 10. You cannot append 5 (V), 50 (L), or 500 (D) multiple times. If you need to append a symbol 4 times use the subtractive form.
# Given an integer, convert it to a Roman numeral.
#
#
#
# Example 1:
#
# Input: num = 3749
#
# Output: "MMMDCCXLIX"
#
# Explanation:
#
# 3000 = MMM as 1000 (M) + 1000 (M) + 1000 (M)
#  700 = DCC as 500 (D) + 100 (C) + 100 (C)
#   40 = XL as 10 (X) less of 50 (L)
#    9 = IX as 1 (I) less of 10 (X)
# Note: 49 is not 1 (I) less of 50 (L) because the conversion is based on decimal places
# Example 2:
#
# Input: num = 58
#
# Output: "LVIII"
#
# Explanation:
#
# 50 = L
#  8 = VIII
# Example 3:
#
# Input: num = 1994
#
# Output: "MCMXCIV"
#
# Explanation:
#
# 1000 = M
#  900 = CM
#   90 = XC
#    4 = IV
#
#
# Constraints:
#
# 1 <= num <= 3999

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# باشه، **ساده، یک‌بار، بدون تکرار** 👇
#
# ---
#
# ## اصل سؤال ۱۲ چیه؟
#
# می‌خوای یک **عدد معمولی (۱ تا ۳۹۹۹)** رو تبدیل کنی به **عدد رومی** طبق قوانین مشخص.
#
# ---
#
# ## ایدهٔ اصلی (مغز مسئله)
#
# عدد رو **از بزرگ به کوچک** می‌شکنیم و هر بار **بزرگ‌ترین نماد ممکن** رو برمی‌داریم.
#
# کل ماجرا همینه.
#
# ---
#
# ## قانون طلایی
#
# همیشه این ترتیب رو در ذهنت داشته باش:
#
# ```
# 1000, 900, 500, 400,
# 100, 90, 50, 40,
# 10, 9, 5, 4,
# 1
# ```
#
# و معادل رومی‌شون:
#
# ```
# M, CM, D, CD,
# C, XC, L, XL,
# X, IX, V, IV,
# I
# ```
#
# ---
#
# ## الگوریتم به زبان خودت (Prompt-Nob style)
#
# 1. یک لیست از `(عدد → نماد)` می‌سازیم (از بزرگ به کوچک)
# 2. از اول لیست حرکت می‌کنیم
# 3. **تا وقتی عدد ≥ مقدار بود**:
#
#    * نمادش رو به جواب اضافه می‌کنیم
#    * مقدارش رو از عدد کم می‌کنیم
# 4. می‌ریم سراغ مورد بعدی
# 5. تموم
#
# ---
#
# ## مثال سریع (۱۹۹۴)
#
# ```
# 1994 ≥ 1000 → M      → باقی: 994
# 994  ≥ 900  → CM     → باقی: 94
# 94   ≥ 90   → XC     → باقی: 4
# 4    ≥ 4    → IV
# ```
#
# نتیجه:
#
# ```
# MCMXCIV
# ```
#
# ---
#
#
#
# </div>

# %%
class Solution:
    def intToRoman(self, num: int) -> str:
        values = [
            (1000, "M"),
            (900,  "CM"),
            (500,  "D"),
            (400,  "CD"),
            (100,  "C"),
            (90,   "XC"),
            (50,   "L"),
            (40,   "XL"),
            (10,   "X"),
            (9,    "IX"),
            (5,    "V"),
            (4,    "IV"),
            (1,    "I")
        ]
        
        res = []
        for val, sym in values:
            while num >= val:
                res.append(sym)
                num -= val
        
        return "".join(res)

# %% [markdown]
# 13. Roman to Integer
# Easy
# Topics
# premium lock icon
# Companies
# Hint
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two ones added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.
#
#
#
# Example 1:
#
# Input: s = "III"
# Output: 3
# Explanation: III = 3.
# Example 2:
#
# Input: s = "LVIII"
# Output: 58
# Explanation: L = 50, V= 5, III = 3.
# Example 3:
#
# Input: s = "MCMXCIV"
# Output: 1994
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.
#
#
# Constraints:
#
# 1 <= s.length <= 15
# s contains only the characters ('I', 'V', 'X', 'L', 'C', 'D', 'M').
# It is guaranteed that s is a valid roman numeral in the range [1, 3999].

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# برعکس قبلی
# </div>

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        val = {
            'I': 1,
            'V': 5,
            'X': 10,
            'L': 50,
            'C': 100,
            'D': 500,
            'M': 1000
        }

        total = 0
        prev = 0

        for ch in reversed(s):
            curr = val[ch]
            if curr < prev:
                total -= curr
            else:
                total += curr
            prev = curr

        return total

# %% [markdown]
# ## 14. Longest Common Prefix
# Easy
# Topics
# premium lock icon
# Companies
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".
#
#
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.
#
#
# Constraints:
#
# 1 <= strs.length <= 200
# 0 <= strs[i].length <= 200
# strs[i] consists of only lowercase English letters if it is non-empty.

# %% [markdown]
# <div style="direction: rtl; white-space: normal; line-height: 1;">
# به دلیل اینکه سوالات کاملا متفرقه هست و من طراحی الگوریتم بلد نیستم
# و میخواهم هر بار کاملا بدون الگو فکر کنم خیلی زمان میبرد به همین دلیل رفتم در لیت کد ۷۵ که انجا با الگوریتم ها شروع کنم و مرحله ای جلو بروم فعلا اینجا تا همان سوال ۱۴ ماند.
# </div>
